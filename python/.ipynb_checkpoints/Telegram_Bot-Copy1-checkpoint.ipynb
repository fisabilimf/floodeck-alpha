# %%
# import pandas as pd
# import numpy as np
# import math
# import matplotlib.pyplot as plt
# from numpy import array
# from numpy import hstack
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# import pymysql
# from datetime import datetime, timedelta
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# import seaborn as sns
# from statsmodels.tsa.seasonal import seasonal_decompose
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# from typing import List
# from typing import Optional
# from sqlalchemy import ForeignKey
# from sqlalchemy import String
# from sqlalchemy.orm import DeclarativeBase
# from sqlalchemy.orm import Mapped
# from sqlalchemy.orm import mapped_column
# from sqlalchemy.orm import relationship
# import random, sqlite3

# %%
# from datetime import datetime
# print(f"Running Water_Elevation.ipynb at: {datetime.now()}")
# %run Water_Elevation.ipynb

# %%
# import time
# from IPython import get_ipython

# def run_notebook():
#     while True:
#         get_ipython().run_line_magic('run', 'Water_Elevation.ipynb')
#         print("Notebook executed at:", time.strftime("%Y-%m-%d %H:%M:%S"))
#         time.sleep(300)  # 300 seconds = 5 minutes

# # Start the loop
# run_notebook()

# %%
# # Database connection
# db_name = "floodeck_alpha"
# db_host = "localhost"
# db_username = "root"
# db_password = ""

# try:
#     conn = pymysql.connect(host=db_host,
#                            port=int(3306),
#                            user=db_username,
#                            password=db_password,
#                            db=db_name)
#     print("Connection successful")
# except Exception as e:
#     print(e)

# %%
# import time
# import threading
# from IPython import get_ipython

# def run_notebook_periodically():
#     while True:
#         get_ipython().run_line_magic('run', 'Sensor_A_Data_Send.ipynb')
#         print("Notebook executed at:", time.strftime("%Y-%m-%d %H:%M:%S"))
#         time.sleep(60)  # 300 seconds = 5 minutes

# # Create and start a thread to run the notebook periodically
# execution_thread = threading.Thread(target=run_notebook_periodically)
# execution_thread.daemon = True  # This ensures the thread will not prevent the program from exiting
# execution_thread.start()

# %%
# import time
# import threading
# from IPython import get_ipython

# def run_notebook_periodically():
#     while True:
#         get_ipython().run_line_magic('run', 'Sensor_B_Data_Send.ipynb')
#         print("Notebook executed at:", time.strftime("%Y-%m-%d %H:%M:%S"))
#         time.sleep(60)  # 300 seconds = 5 minutes

# # Create and start a thread to run the notebook periodically
# execution_thread = threading.Thread(target=run_notebook_periodically)
# execution_thread.daemon = True  # This ensures the thread will not prevent the program from exiting
# execution_thread.start()

# %%
import time
import threading
from IPython import get_ipython

def run_notebook_periodically():
    while True:
        get_ipython().run_line_magic('run', 'Water_Elevation.ipynb')
        print("Notebook executed at:", time.strftime("%Y-%m-%d %H:%M:%S"))
        time.sleep(60)  # 300 seconds = 5 minutes

# Create and start a thread to run the notebook periodically
execution_thread = threading.Thread(target=run_notebook_periodically)
execution_thread.daemon = True  # This ensures the thread will not prevent the program from exiting
execution_thread.start()
# Out:
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# rll<l|dc|rccg'lg'#plrl{dpod#o|cnoll`g'l`orocllpg{cn|cogl`nol`'{ۓnc`{ocĒ Ǐxl glg;o|dd`b|rl'gl`{l$
# Incorrect data format received
# SDK:2.2.2-dev(38a443e)/Core:3.1.2=30102000/lwIP:STABLE-2_1_3_RELEASE/glue:1.2-65-g06164fb/BearSSL:b024386
# Incorrect data format received
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# [{'Timestamp': '2024-07-08 21:39:20', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:39:22', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:39:23', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:39:24', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:39:25', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:39:20     BRNTS1     SNSR1         32.0      50.0     27.39
# 1  2024-07-08 21:39:22     BRNTS1     SNSR1         32.0      50.0     28.25
# 2  2024-07-08 21:39:23     BRNTS1     SNSR1         32.0      50.0     27.39
# 3  2024-07-08 21:39:24     BRNTS1     SNSR1         32.0      50.0     27.39
# 4  2024-07-08 21:39:25     BRNTS1     SNSR1         32.0      50.0     28.25
#
#    RainValue
# 0      -0.05
# 1      -0.05
# 2      -0.05
# 3      -0.05
# 4      -0.05
# 2024-07-08 21:39:20
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.05
# Connection successful
# SAFE
# INSERT INTO sensor_a (water_post_code, sensor_a_temperature, sensor_a_humidity, sensor_a_scan_water_height, sensor_a_raindrop, sensor_a_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:39:20
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.05
# SAFE
# 7.609999999999999
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1773559220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_a = pd.read_sql_query(water_height_a_query, conn, params=[water_post_code_a])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099
# Epoch 2/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042
# Epoch 3/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048
# Epoch 4/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033
# Epoch 5/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# [[[0.04595695]
#   [0.        ]
#   [0.0796975 ]]]
# 8.17202886879444
# 2024-07-08 21:39:20
# 2024-07-08 21:44:20
#            created_at  prediction_sensor_a_scan_water_height
# 0 2024-07-08 21:44:20                                   8.17
# 0   8.17
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:44:20
# Name: created_at, dtype: datetime64[ns]
# INSERT INTO forecasting (river_code, prediction_sensor_a_scan_water_height, created_at, water_sensor_a_status) VALUES (%s, %s, %s, %s)
# Prediction saved to database
# Last inserted record:    id river_code  prediction_sensor_a_scan_water_height  \
# 0  26     BRNTS1                                   8.17
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   0.00                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE
#
#            created_at           updated_at
# 0 2024-07-08 21:44:20  0000-00-00 00:00:00
# 7.609999999999999
# 0   8.17
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:44:20
# Name: created_at, dtype: datetime64[ns]
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# {ll|d|db<sc#nglgncp${$sdpglco<cgndd`'o$`gsobd$p'{ܜco|#nod`no$`'{gc s'c`Ǐpl`'$gsn|$l`c|rlggd`;$d
# Incorrect data format received
# SDK:2.2.2-dev(38a443e)/Core:3.1.2=30102000/lwIP:STABLE-2_1_3_RELEASE/glue:1.2-65-g06164fb/BearSSL:b024386
# Incorrect data format received
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: 0.00
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.39
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.38
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.38
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.38
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.38
# [{'Timestamp': '2024-07-08 21:39:40', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': 0.0}, {'Timestamp': '2024-07-08 21:39:41', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.39}, {'Timestamp': '2024-07-08 21:39:42', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.38}, {'Timestamp': '2024-07-08 21:39:43', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.38}, {'Timestamp': '2024-07-08 21:39:44', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.38}, {'Timestamp': '2024-07-08 21:39:45', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.38}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:39:40     BRNTS1     SNSR2        32.00     50.00     28.79
# 1  2024-07-08 21:39:41     BRNTS1     SNSR2        32.00     50.00     27.90
# 2  2024-07-08 21:39:42     BRNTS1     SNSR2        32.00     50.00     28.79
# 3  2024-07-08 21:39:43     BRNTS1     SNSR2        32.00     50.00     28.79
# 4  2024-07-08 21:39:44     BRNTS1     SNSR2        32.00     50.00     27.90
#
#    RainValue
# 0       0.00
# 1      -0.39
# 2      -0.38
# 3      -0.38
# 4      -0.38
# 2024-07-08 21:39:40
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.79
# 0.0
# Connection successful
# SAFE
# INSERT INTO sensor_b (water_post_code, sensor_b_temperature, sensor_b_humidity, sensor_b_scan_water_height, sensor_b_raindrop, sensor_b_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:39:40
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.79
# 0.0
# SAFE
# 6.210000000000001
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3001575197.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_b = pd.read_sql_query(water_height_b_query, conn, params=[water_post_code_b])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0047
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8237e-04
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9125e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# [[[0.08128942]
#   [0.08128942]
#   [0.        ]]]
# 7.0953905031457545
# 2024-07-08 21:39:40
# 2024-07-08 21:44:40
#            created_at  prediction_sensor_b_scan_water_height
# 0 2024-07-08 21:44:40                                   7.10
# 0   7.10
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-08 21:44:40
# Name: created_at, dtype: datetime64[ns]
# Last inserted record:    id river_code  prediction_sensor_a_scan_water_height  \
# 0  26     BRNTS1                                   8.17
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   7.10                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE                  SAFE
#
#            created_at           updated_at
# 0 2024-07-08 21:44:20  0000-00-00 00:00:00
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# 6.210000000000001
# 0   7.10
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-08 21:44:40
# Name: created_at, dtype: datetime64[ns]
# BRNTS1
# Connection successful
# 7.609999999999999
# 6.210000000000001
# 30.0
# 20.0
# 0.001
# 60.0
# 2.0
# 0.25
# 30.0
# 8.577140406531925
# 0.8543475265427426
# 7.182826236728628
# SNSR1
# SNSR2
# 2024-07-08 21:39:40
# 0   2024-07-08 21:44:40
# Name: created_at, dtype: datetime64[ns]
# Data saved to database
# 8.17202886879444
# 7.0953905031457545
# 7.744855105523069
# SAFE
# Notebook executed at: 2024-07-08 21:39:49
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3874786821.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_data = pd.read_sql_query(river_data_query, conn, params=[river_code])
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# [{'Timestamp': '2024-07-08 21:40:47', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:49', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:51', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:52', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:53', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:54', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:40:56', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:40:47     BRNTS1     SNSR1        32.00     50.00     27.39
# 1  2024-07-08 21:40:49     BRNTS1     SNSR1        32.00     50.00     27.39
# 2  2024-07-08 21:40:51     BRNTS1     SNSR1        32.00     50.00     27.39
# 3  2024-07-08 21:40:52     BRNTS1     SNSR1        32.00     50.00     27.39
# 4  2024-07-08 21:40:53     BRNTS1     SNSR1        32.00     50.00     28.25
#
#    RainValue
# 0      -0.05
# 1      -0.05
# 2      -0.05
# 3      -0.05
# 4      -0.05
# 2024-07-08 21:40:47
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.05
# Connection successful
# SAFE
# INSERT INTO sensor_a (water_post_code, sensor_a_temperature, sensor_a_humidity, sensor_a_scan_water_height, sensor_a_raindrop, sensor_a_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:40:47
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.05
# SAFE
# 7.609999999999999
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1773559220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_a = pd.read_sql_query(water_height_a_query, conn, params=[water_post_code_a])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0102
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# [[[0.       ]
#   [0.0796975]
#   [0.0796975]]]
# 7.998283465057611
# 2024-07-08 21:40:47
# 2024-07-08 21:45:47
#            created_at  prediction_sensor_a_scan_water_height
# 0 2024-07-08 21:45:47                                   8.00
# 0   8.00
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:45:47
# Name: created_at, dtype: datetime64[ns]
# INSERT INTO forecasting (river_code, prediction_sensor_a_scan_water_height, created_at, water_sensor_a_status) VALUES (%s, %s, %s, %s)
# Prediction saved to database
# Last inserted record:    id river_code  prediction_sensor_a_scan_water_height  \
# 0  27     BRNTS1                                   8.00
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   0.00                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE
#
#            created_at           updated_at
# 0 2024-07-08 21:45:47  0000-00-00 00:00:00
# 7.609999999999999
# 0   8.00
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:45:47
# Name: created_at, dtype: datetime64[ns]
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.35
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.76 cm, Rain: -0.35
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.35
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.35
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.35
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.34
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.79 cm, Rain: -0.34
# [{'Timestamp': '2024-07-08 21:41:02', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.35}, {'Timestamp': '2024-07-08 21:41:03', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.76, 'RainValue': -0.35}, {'Timestamp': '2024-07-08 21:41:04', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.35}, {'Timestamp': '2024-07-08 21:41:05', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.35}, {'Timestamp': '2024-07-08 21:41:07', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.35}, {'Timestamp': '2024-07-08 21:41:08', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.34}, {'Timestamp': '2024-07-08 21:41:09', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.79, 'RainValue': -0.34}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:41:02     BRNTS1     SNSR2        32.00     50.00     28.79
# 1  2024-07-08 21:41:03     BRNTS1     SNSR2        32.00     50.00     28.76
# 2  2024-07-08 21:41:04     BRNTS1     SNSR2        32.00     50.00     28.79
# 3  2024-07-08 21:41:05     BRNTS1     SNSR2        32.00     50.00     28.79
# 4  2024-07-08 21:41:07     BRNTS1     SNSR2        32.00     50.00     28.79
#
#    RainValue
# 0      -0.35
# 1      -0.35
# 2      -0.35
# 3      -0.35
# 4      -0.35
# 2024-07-08 21:41:02
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.79
# -0.35
# Connection successful
# SAFE
# INSERT INTO sensor_b (water_post_code, sensor_b_temperature, sensor_b_humidity, sensor_b_scan_water_height, sensor_b_raindrop, sensor_b_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:41:02
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.79
# -0.35
# SAFE
# 6.210000000000001
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3001575197.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_b = pd.read_sql_query(water_height_b_query, conn, params=[water_post_code_b])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0044
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7924e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# [[[0.08128942]
#   [0.        ]
#   [0.        ]]]
# 7.073185669183731
# 2024-07-08 21:41:02
# 2024-07-08 21:46:02
#            created_at  prediction_sensor_b_scan_water_height
# 0 2024-07-08 21:46:02                                   7.07
# 0   7.07
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-08 21:46:02
# Name: created_at, dtype: datetime64[ns]
# Last inserted record:    id river_code  prediction_sensor_a_scan_water_height  \
# 0  27     BRNTS1                                   8.00
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   7.07                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE                  SAFE
#
#            created_at           updated_at
# 0 2024-07-08 21:45:47  0000-00-00 00:00:00
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# 6.210000000000001
# 0   7.07
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-08 21:46:02
# Name: created_at, dtype: datetime64[ns]
# BRNTS1
# Connection successful
# 7.609999999999999
# 6.210000000000001
# 30.0
# 20.0
# 0.001
# 60.0
# 2.0
# 0.25
# 30.0
# 8.577140406531925
# 0.8543475265427426
# 7.182826236728628
# SNSR1
# SNSR2
# 2024-07-08 21:41:02
# 0   2024-07-08 21:46:02
# Name: created_at, dtype: datetime64[ns]
# Data saved to database
# 7.998283465057611
# 7.073185669183731
# 7.57110970178624
# SAFE
# Notebook executed at: 2024-07-08 21:41:15
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3874786821.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_data = pd.read_sql_query(river_data_query, conn, params=[river_code])
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.21 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.05
# [{'Timestamp': '2024-07-08 21:42:09', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:10', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.21, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:11', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:12', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:13', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:14', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:15', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}, {'Timestamp': '2024-07-08 21:42:16', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.05}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:42:09     BRNTS1     SNSR1        32.00     50.00     28.25
# 1  2024-07-08 21:42:10     BRNTS1     SNSR1        32.00     50.00     28.21
# 2  2024-07-08 21:42:11     BRNTS1     SNSR1        32.00     50.00     28.25
# 3  2024-07-08 21:42:12     BRNTS1     SNSR1        32.00     50.00     28.25
# 4  2024-07-08 21:42:13     BRNTS1     SNSR1        32.00     50.00     28.25
#
#    RainValue
# 0      -0.05
# 1      -0.05
# 2      -0.05
# 3      -0.05
# 4      -0.05
# 2024-07-08 21:42:09
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 28.25
# -0.05
# Connection successful
# SAFE
# INSERT INTO sensor_a (water_post_code, sensor_a_temperature, sensor_a_humidity, sensor_a_scan_water_height, sensor_a_raindrop, sensor_a_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:42:09
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 28.25
# -0.05
# SAFE
# 6.75
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1773559220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_a = pd.read_sql_query(water_height_a_query, conn, params=[water_post_code_a])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0131
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# 2024-07-08 21:42:21,146 - tensorflow - WARNING - 5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023BDB8E7CE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# [[[0.0796975 ]
#   [0.0796975 ]
#   [0.02966841]]]
# 7.989695491790771
# 2024-07-08 21:42:09
# 2024-07-08 21:47:09
#            created_at  prediction_sensor_a_scan_water_height
# 0 2024-07-08 21:47:09                                   7.99
# 0   7.99
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:47:09
# Name: created_at, dtype: datetime64[ns]
# INSERT INTO forecasting (river_code, prediction_sensor_a_scan_water_height, created_at, water_sensor_a_status) VALUES (%s, %s, %s, %s)
# Prediction saved to database
# Last inserted record:    id river_code  prediction_sensor_a_scan_water_height  \
# 0  28     BRNTS1                                   7.99
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   0.00                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE
#
#            created_at           updated_at
# 0 2024-07-08 21:47:09  0000-00-00 00:00:00
# 6.75
# 0   7.99
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-08 21:47:09
# Name: created_at, dtype: datetime64[ns]
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.76 cm, Rain: -0.31
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.31
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.76 cm, Rain: -0.31
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.30
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.30
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.76 cm, Rain: -0.30
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.76 cm, Rain: -0.30
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.30
# [{'Timestamp': '2024-07-08 21:42:22', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.76, 'RainValue': -0.31}, {'Timestamp': '2024-07-08 21:42:23', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.31}, {'Timestamp': '2024-07-08 21:42:24', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.76, 'RainValue': -0.31}, {'Timestamp': '2024-07-08 21:42:25', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.3}, {'Timestamp': '2024-07-08 21:42:26', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.3}, {'Timestamp': '2024-07-08 21:42:27', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.76, 'RainValue': -0.3}, {'Timestamp': '2024-07-08 21:42:29', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.76, 'RainValue': -0.3}, {'Timestamp': '2024-07-08 21:42:30', 'River Code': 'BRNTS1', 'Post Code': 'SNSR2', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.9, 'RainValue': -0.3}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-08 21:42:22     BRNTS1     SNSR2        32.00     50.00     28.76
# 1  2024-07-08 21:42:23     BRNTS1     SNSR2        32.00     50.00     27.90
# 2  2024-07-08 21:42:24     BRNTS1     SNSR2        32.00     50.00     28.76
# 3  2024-07-08 21:42:25     BRNTS1     SNSR2        32.00     50.00     27.90
# 4  2024-07-08 21:42:26     BRNTS1     SNSR2        32.00     50.00     27.90
#
#    RainValue
# 0      -0.31
# 1      -0.31
# 2      -0.31
# 3      -0.30
# 4      -0.30
# 2024-07-08 21:42:22
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.76
# -0.31
# Connection successful
# SAFE
# INSERT INTO sensor_b (water_post_code, sensor_b_temperature, sensor_b_humidity, sensor_b_scan_water_height, sensor_b_raindrop, sensor_b_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-08 21:42:22
# SNSR2
# BRNTS1
# 32.0
# 50.0
# 28.76
# -0.31
# SAFE
# 6.239999999999998
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3001575197.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_b = pd.read_sql_query(water_height_b_query, conn, params=[water_post_code_b])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0054
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7544e-04
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5573e-04
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2396e-04
# 2024-07-08 21:42:34,719 - tensorflow - WARNING - 6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023BDB9AB560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# ...
#   water_height_b = pd.read_sql_query(water_height_b_query, conn, params=[water_post_code_b])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0044
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7202e-04
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5512e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# [[[0.1226349]
#   [0.1226349]
#   [0.1226349]]]
# 7.6253088850527995
# 2024-07-09 00:34:54
# 2024-07-09 00:39:54
#            created_at  prediction_sensor_b_scan_water_height
# 0 2024-07-09 00:39:54                                   7.63
# 0   7.63
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-09 00:39:54
# Name: created_at, dtype: datetime64[ns]
# Last inserted record:     id river_code  prediction_sensor_a_scan_water_height  \
# 0  147     BRNTS1                                   7.47
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   7.63                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE                  SAFE
#
#            created_at           updated_at
# 0 2024-07-09 00:39:40  0000-00-00 00:00:00
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# 7.960000000000001
# 0   7.63
# Name: prediction_sensor_b_scan_water_height, dtype: float64
# 0   2024-07-09 00:39:54
# Name: created_at, dtype: datetime64[ns]
# BRNTS1
# Connection successful
# 6.75
# 7.960000000000001
# 30.0
# 20.0
# 0.001
# 60.0
# 2.0
# 0.25
# 30.0
# 8.577140406531925
# 0.8543475265427426
# 6.322826236728629
# SNSR1
# SNSR2
# 2024-07-09 00:34:54
# 0   2024-07-09 00:39:54
# Name: created_at, dtype: datetime64[ns]
# Data saved to database
# 7.467530221045017
# 7.6253088850527995
# 7.040356457773646
# SAFE
# Notebook executed at: 2024-07-09 00:35:06
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3874786821.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_data = pd.read_sql_query(river_data_query, conn, params=[river_code])
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.39 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.03
# Sensor Post Code: SNSR1 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 28.25 cm, Rain: -0.03
# [{'Timestamp': '2024-07-09 00:36:07', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:08', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:09', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:10', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:11', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:12', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:13', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 27.39, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:14', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.03}, {'Timestamp': '2024-07-09 00:36:15', 'River Code': 'BRNTS1', 'Post Code': 'SNSR1', 'Temperature': 32.0, 'Humidity': 50.0, 'Distance': 28.25, 'RainValue': -0.03}]
#              Timestamp River Code Post Code  Temperature  Humidity  Distance  \
# 0  2024-07-09 00:36:07     BRNTS1     SNSR1        32.00     50.00     27.39
# 1  2024-07-09 00:36:08     BRNTS1     SNSR1        32.00     50.00     28.25
# 2  2024-07-09 00:36:09     BRNTS1     SNSR1        32.00     50.00     27.39
# 3  2024-07-09 00:36:10     BRNTS1     SNSR1        32.00     50.00     27.39
# 4  2024-07-09 00:36:11     BRNTS1     SNSR1        32.00     50.00     28.25
#
#    RainValue
# 0      -0.03
# 1      -0.03
# 2      -0.03
# 3      -0.03
# 4      -0.03
# 2024-07-09 00:36:07
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.03
# Connection successful
# SAFE
# INSERT INTO sensor_a (water_post_code, sensor_a_temperature, sensor_a_humidity, sensor_a_scan_water_height, sensor_a_raindrop, sensor_a_status, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s)
# Data saved to database
# 2024-07-09 00:36:07
# SNSR1
# BRNTS1
# 32.0
# 50.0
# 27.39
# -0.03
# SAFE
# 7.609999999999999
# Connection successful
# Epoch 1/5
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\651341619.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sensor_placement = pd.read_sql_query(sensor_placement_query, conn, params=[post_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2419725278.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_depth = pd.read_sql_query(river_depth_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1006563404.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_safe_height = pd.read_sql_query(river_safe_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\268853509.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_warning_height = pd.read_sql_query(river_warning_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3464102430.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   river_danger_height = pd.read_sql_query(river_danger_height_query, conn, params=[river_code])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1773559220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   water_height_a = pd.read_sql_query(water_height_a_query, conn, params=[water_post_code_a])
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\sequence.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   targets = np.array([self.targets[row] for row in rows])
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0030
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9320e-04
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# [[[0.0796975 ]
#   [0.02966841]
#   [0.0796975 ]]]
# 7.382011405080557
# 2024-07-09 00:36:07
# 2024-07-09 00:41:07
#            created_at  prediction_sensor_a_scan_water_height
# 0 2024-07-09 00:41:07                                   7.38
# 0   7.38
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-09 00:41:07
# Name: created_at, dtype: datetime64[ns]
# INSERT INTO forecasting (river_code, prediction_sensor_a_scan_water_height, created_at, water_sensor_a_status) VALUES (%s, %s, %s, %s)
# Prediction saved to database
# Last inserted record:     id river_code  prediction_sensor_a_scan_water_height  \
# 0  148     BRNTS1                                   7.38
#
#    prediction_sensor_b_scan_water_height  prediction_water_elevation  \
# 0                                   0.00                        0.00
#
#   water_sensor_a_status water_sensor_b_status water_status  \
# 0                  SAFE
#
#            created_at           updated_at
# 0 2024-07-09 00:41:07  0000-00-00 00:00:00
# 7.609999999999999
# 0   7.38
# Name: prediction_sensor_a_scan_water_height, dtype: float64
# 0   2024-07-09 00:41:07
# Name: created_at, dtype: datetime64[ns]
# COM3 - USB-SERIAL CH340 (COM3)
# COM4 - USB-SERIAL CH340 (COM4)
# COM1 - Communications Port (COM1)
# COM2 - Communications Port (COM2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3868589220.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_check = pd.read_sql_query("SELECT * FROM forecasting ORDER BY id DESC LIMIT 1", conn)
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.04 cm, Rain: -0.24
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.90 cm, Rain: -0.24
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.04 cm, Rain: -0.24
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.04 cm, Rain: -0.24
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.04 cm, Rain: -0.24
# Sensor Post Code: SNSR2 , River Code: BRNTS1 , Temperature: 32.00 C, Humidity: 50.00 %, Distance: 27.04 cm, Rain: -0.24
# Exception in thread Thread-5 (run_notebook_periodically):
# Traceback (most recent call last):
#   File "C:\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Python312\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\1003252849.py", line 7, in run_notebook_periodically
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\3070639497.py", line 1, in <module>
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\4273463804.py", line 1, in <module>
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2594567836.py", line 52, in <module>
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_9324\2594567836.py", line 26, in read_serial_data
#   File "C:\Python312\Lib\site-packages\serial\serialwin32.py", line 259, in in_waiting
#     raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
# serial.serialutil.SerialException: ClearCommError failed (PermissionError(13, 'Access is denied.', None, 5))

# %%
import logging
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, MessageHandler, filters, ContextTypes, JobQueue

import nest_asyncio
import asyncio

DANGER = "DANGER"

# Global variable to store the chat ID
chat_id = None

# Enable logging
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level=logging.INFO
)

logger = logging.getLogger(__name__)

# Your bot token here
TOKEN = '7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw'

async def start(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /start is issued."""
    global chat_id
    chat_id = update.effective_chat.id
    await update.message.reply_text('Start the services')

async def help_command(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /help is issued."""
    await update.message.reply_text('Use any command available')

#Point A and Point B now
async def water_point(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /water_point is issued."""
    await update.message.reply_text(f'Water height of Point A and Point B: \n{sensor_a_scan_water_height}, {point_a_status}, \n{sensor_b_scan_water_height}, {point_b_status}, \n{latest_timestamp}')

#Prediction of Point A and Point B now
async def prediction_water_point(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /prediction_water_point is issued."""
    await update.message.reply_text(f'Prediction water height of Point A and Point B: \n{predicted_value_a.iloc[0]}, \n{predicted_value_b.iloc[0]}, \n{future_timestamp.iloc[0]}')

#Water Elevation 
async def water_elevation(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /water_elevation is issued."""
    await update.message.reply_text(f'Water elevation: {Hx}, \n{elevation_status}, \n{latest_timestamp}')

#Water Predicted Elevation
async def predicted_water_elevation(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Send a message when the command /predicted_water_elevation is issued."""
    await update.message.reply_text(f'Predicted water elevation prediction: {predicted_Hx}, \n{elevation_status}, \n{latest_timestamp}')

async def check_danger_status(context: ContextTypes.DEFAULT_TYPE) -> None:
    """Check if any point is in DANGER status and send a message."""
    global chat_id
    if chat_id is not None and (point_a_status == DANGER or point_b_status == DANGER or elevation_status == DANGER):
        danger_message = (f'ALERT! Danger status detected: \n'
                          f'Point A: {sensor_a_scan_water_height}, {point_a_status}\n'
                          f'Point B: {sensor_b_scan_water_height}, {point_b_status}\n'
                          f'Water Elevation: {Hx}, {elevation_status}\n'
                          f'{latest_timestamp}')
        await context.bot.send_message(chat_id=chat_id, text=danger_message)

async def echo(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    """Echo the user message."""
    user_text = update.message.text
    await update.message.reply_text(user_text)

async def main() -> None:
    """Start the bot."""
    application = ApplicationBuilder().token(TOKEN).build()

    application.add_handler(CommandHandler("start", start))
    application.add_handler(CommandHandler("help", help_command))
    application.add_handler(CommandHandler("water_point", water_point))
    application.add_handler(CommandHandler("prediction_water_point", prediction_water_point))
    application.add_handler(CommandHandler("water_elevation", water_elevation))
    application.add_handler(CommandHandler("predicted_water_elevation", predicted_water_elevation))
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, echo))

    # Run the check_danger_status function periodically (e.g., every minute)
    job_queue = application.job_queue
    job_queue.run_repeating(check_danger_status, interval=60, first=0)
    
    await application.initialize()
    await application.start()
    await application.updater.start_polling()


if __name__ == '__main__':
    nest_asyncio.apply()
    asyncio.run(main())
# Out:
# 2024-07-08 21:39:17,050 - apscheduler.scheduler - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-07-08 21:39:18,115 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getMe "HTTP/1.1 200 OK"
# 2024-07-08 21:39:18,117 - apscheduler.scheduler - INFO - Added job "check_danger_status" to job store "default"
# 2024-07-08 21:39:18,119 - apscheduler.scheduler - INFO - Scheduler started
# 2024-07-08 21:39:18,120 - telegram.ext.Application - INFO - Application started
# 2024-07-08 21:39:18,489 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/deleteWebhook "HTTP/1.1 200 OK"
# 2024-07-08 21:39:32,198 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:39:43,380 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:39:53,379 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:02,353 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:11,296 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:17,061 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:41:17 UTC)" (scheduled at 2024-07-09 04:40:17.050133+00:00)
# 2024-07-08 21:40:17,062 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:41:17 UTC)" executed successfully
# 2024-07-08 21:40:20,556 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:30,761 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:42,432 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:40:54,856 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:07,476 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:18,800 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:23,335 - apscheduler.executors.default - WARNING - Run time of job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:42:17 UTC)" was missed by 0:00:06.285836
# 2024-07-08 21:41:28,963 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:38,108 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:46,289 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:41:54,503 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:42:03,558 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:42:13,557 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:42:17,098 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:43:17 UTC)" (scheduled at 2024-07-09 04:42:17.050133+00:00)
# 2024-07-08 21:42:17,099 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:43:17 UTC)" executed successfully
# 2024-07-08 21:42:24,629 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:42:36,772 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:42:50,173 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:43:03,296 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:43:14,835 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:43:25,062 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:43:26,290 - apscheduler.executors.default - WARNING - Run time of job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:44:17 UTC)" was missed by 0:00:09.240402
# 2024-07-08 21:43:34,290 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:43:55,177 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:44:03,749 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:44:13,193 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:44:17,070 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:45:17 UTC)" (scheduled at 2024-07-09 04:44:17.050133+00:00)
# 2024-07-08 21:44:17,071 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:45:17 UTC)" executed successfully
# 2024-07-08 21:44:23,787 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:44:35,327 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:44:48,072 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:02,088 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:15,206 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:29,027 - apscheduler.executors.default - WARNING - Run time of job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:46:17 UTC)" was missed by 0:00:11.977015
# 2024-07-08 21:45:29,149 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:39,836 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:49,143 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:45:57,383 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:46:04,824 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:46:11,873 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-08 21:46:17,056 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04:47:17 UTC)" (scheduled at 2024-07-09 04:46:17.050133+00:00)
# 2024-07-08 21:46:17,056 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-09 04
- httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:38:17,059 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-11 05:39:17 UTC)" (scheduled at 2024-07-11 05:38:17.050133+00:00)
# 2024-07-10 22:38:17,059 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-11 05:39:17 UTC)" executed successfully
# 2024-07-10 22:38:18,787 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:38:28,995 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:38:39,199 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:38:49,404 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:38:59,612 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:39:09,819 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:39:17,061 - apscheduler.executors.default - INFO - Running job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-11 05:40:17 UTC)" (scheduled at 2024-07-11 05:39:17.050133+00:00)
# 2024-07-10 22:39:17,063 - apscheduler.executors.default - INFO - Job "check_danger_status (trigger: interval[0:01:00], next run at: 2024-07-11 05:40:17 UTC)" executed successfully
# 2024-07-10 22:39:20,025 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:39:30,265 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:39:40,469 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:39:50,682 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"
# 2024-07-10 22:40:00,889 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7167249563:AAFtTw4yC-fFnMXrsmJIcQacbt4Tt5tupDw/getUpdates "HTTP/1.1 200 OK"

# %%
import pandas as pd
import pymysql

# %%
# Database connection
db_name = "floodeck_alpha"
db_host = "localhost"
db_username = "root"
db_password = ""

try:
    conn = pymysql.connect(host=db_host,
                           port=int(3306),
                           user=db_username,
                           password=db_password,
                           db=db_name)
    print("Connection successful")
except Exception as e:
    print(e)
# Out:
# Connection successful

# %%
import time
import threading
import requests
import schedule
import pandas as pd
import sqlite3

# Assuming conn is a valid database connection
# conn = sqlite3.connect('your_database.db')

def fetch_subscribers():
    query = "SELECT phone_number, whatsapp_api FROM whatsapp_subscribers"
    return pd.read_sql_query(query, conn)

def send_whatsapp_message(phone_number, message, apikey, retries=3):
    url = f"https://api.callmebot.com/whatsapp.php?phone={phone_number}&text={message}&apikey={apikey}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.status_code, response.text
    except requests.RequestException as e:
        if retries > 0:
            time.sleep(60)  # Wait for 5 seconds before retrying
            return send_whatsapp_message(phone_number, message, apikey, retries-1)
        else:
            return None, str(e)

def check_and_send_messages():
    # Ensure these variables are defined and updated appropriately
    global point_a_status, point_b_status, elevation_status
    global sensor_a_scan_water_height, sensor_b_scan_water_height, Hx, latest_timestamp

    if point_a_status == "DANGER" or point_b_status == "DANGER" or elevation_status == "DANGER":
        danger_message = (f'ALERT! Danger status detected: \n'
                          f'Point A: {sensor_a_scan_water_height}, {point_a_status}\n'
                          f'Point B: {sensor_b_scan_water_height}, {point_b_status}\n'
                          f'Water Elevation: {Hx}, {elevation_status}\n'
                          f'{latest_timestamp}')
        message = danger_message

        # Fetch the latest subscribers
        subscribers_df = fetch_subscribers()

        # Send messages to all subscribers
        for index, row in subscribers_df.iterrows():
            phone_number = row['phone_number']
            apikey = row['whatsapp_api']
            status_code, response_text = send_whatsapp_message(phone_number, message, apikey)
            print(f"Phone Number: {phone_number}")
            print(f"Status Code: {status_code}")
            print(f"Response Text: {response_text}\n")

def schedule_checker():
    while True:
        schedule.run_pending()
        time.sleep(5)

# Schedule the task to run every minute
schedule.every(5).minutes.do(check_and_send_messages)

# Start the background thread
thread = threading.Thread(target=schedule_checker)
thread.daemon = True
thread.start()
